# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Specify the file paths for the CSV files
file_path_2020 = "resources/athletic_sales_2020.csv"
file_path_2021 = "resources/athletic_sales_2021.csv"

# Read the CSV files into DataFrames
df_2020 = pd.read_csv(file_path_2020)
df_2021 = pd.read_csv(file_path_2021)

# %%
# Display the 2020 sales DataFrame
display(df_2020.head())
display(df_2020.tail())
# Out:
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732       1/1/20  Northeast      New York
# 1  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3  Foot Locker      1185732       1/1/20  Northeast      New York
# 4  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
#
#            city                product  price_per_unit  units_sold  \
# 0      New York  Men's Street Footwear              50        1200
# 1  Philadelphia        Women's Apparel              68          83
# 2  Philadelphia        Women's Apparel              75         275
# 3      New York  Men's Street Footwear              34         384
# 4  Philadelphia        Women's Apparel              53          83
#
#    total_sales  operating_profit sales_method
# 0       600000         300000.00     In-store
# 1         5644           2426.92       Online
# ...

# %%
# Display the 2021 sales DataFrame
display(df_2021.head())
display(df_2021.tail())
# Out:
#     retailer  retailer_id invoice_date   region       state           city  \
# 0  West Gear      1128299       1/1/21     West  California  San Francisco
# 1  West Gear      1128299       1/1/21     West  California  San Francisco
# 2     Kohl's      1189833       1/1/21  Midwest     Montana       Billings
# 3     Kohl's      1189833       1/1/21  Midwest     Montana       Billings
# 4  West Gear      1128299       1/1/21     West  California  San Francisco
#
#                    product  price_per_unit  units_sold  total_sales  \
# 0  Men's Athletic Footwear              65         750       487500
# 1  Men's Athletic Footwear              51         233        11883
# 2            Men's Apparel              50         275       137500
# 3            Men's Apparel              47          77         3619
# 4  Men's Athletic Footwear              64         225        14400
#
#    operating_profit sales_method
# 0         121875.00       Outlet
# 1           3208.41       Outlet
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
(df_2020.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1297 entries, 0 to 1296
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          1297 non-null   object
#  1   retailer_id       1297 non-null   int64
#  2   invoice_date      1297 non-null   object
#  3   region            1297 non-null   object
#  4   state             1297 non-null   object
#  5   city              1297 non-null   object
#  6   product           1297 non-null   object
#  7   price_per_unit    1297 non-null   int64
#  8   units_sold        1297 non-null   int64
#  9   total_sales       1297 non-null   int64
#  10  operating_profit  1297 non-null   float64
#  11  sales_method      1297 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 121.7+ KB

# %%
# Check the 2021 sales data types.
(df_2021.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8346 entries, 0 to 8345
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          8346 non-null   object
#  1   retailer_id       8346 non-null   int64
#  2   invoice_date      8346 non-null   object
#  3   region            8346 non-null   object
#  4   state             8346 non-null   object
#  5   city              8346 non-null   object
#  6   product           8346 non-null   object
#  7   price_per_unit    8346 non-null   int64
#  8   units_sold        8346 non-null   int64
#  9   total_sales       8346 non-null   int64
#  10  operating_profit  8346 non-null   float64
#  11  sales_method      8346 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 782.6+ KB

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.

combined_df = pd.concat([df_2020, df_2021], axis=0, join='inner').reset_index(drop=True)

(combined_df)
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9639  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9640       Amazon      1185732     12/31/21  Northeast         Maine
# 9641       Amazon      1185732     12/31/21  Northeast         Maine
# 9642  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Check if any values are null in the combined DataFrame
null_values = combined_df.isnull().sum()

# Print the number of null values in each column
(null_values)
# Out:
# retailer            0
# retailer_id         0
# invoice_date        0
# region              0
# state               0
# city                0
# product             0
# price_per_unit      0
# units_sold          0
# total_sales         0
# operating_profit    0
# sales_method        0
# dtype: int64

# %%
# Check the data type of each column

# Combine the DataFrames by rows using an inner join and reset the index
combined_sales = pd.concat([df_2020, df_2021]).reset_index(drop=True)

# Display non-null count and data type of each column
(combined_sales.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9643 entries, 0 to 9642
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          9643 non-null   object
#  1   retailer_id       9643 non-null   int64
#  2   invoice_date      9643 non-null   object
#  3   region            9643 non-null   object
#  4   state             9643 non-null   object
#  5   city              9643 non-null   object
#  6   product           9643 non-null   object
#  7   price_per_unit    9643 non-null   int64
#  8   units_sold        9643 non-null   int64
#  9   total_sales       9643 non-null   int64
#  10  operating_profit  9643 non-null   float64
#  11  sales_method      9643 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 904.2+ KB

# %%
# Convert the "invoice_date" to a datetime datatype

# Combine the DataFrames by rows using an inner join and reset the index
combined_sales = pd.concat([df_2020, df_2021]).reset_index(drop=True)

# Convert the "invoice_date" column to datetime data type with explicit date format
combined_sales['invoice_date'] = pd.to_datetime(combined_sales['invoice_date'], format='%m/%d/%y')

# Display the DataFrame with the specified format
(combined_sales)
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732   2020-01-01  Northeast      New York
# 1     Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 2     Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 3     Foot Locker      1185732   2020-01-01  Northeast      New York
# 4     Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 9639  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 9640       Amazon      1185732   2021-12-31  Northeast         Maine
# 9641       Amazon      1185732   2021-12-31  Northeast         Maine
# 9642  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Confirm that the "invoice_date" data type has been changed.

# Combine the DataFrames by rows using an inner join and reset the index
combined_sales = pd.concat([df_2020, df_2021]).reset_index(drop=True)

# Convert the "invoice_date" column to datetime data type with the correct format
combined_sales['invoice_date'] = pd.to_datetime(combined_sales['invoice_date'], format='%m/%d/%y')

# Display a detailed summary of the DataFrame
(combined_sales.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9643 entries, 0 to 9642
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          9643 non-null   object
#  1   retailer_id       9643 non-null   int64
#  2   invoice_date      9643 non-null   datetime64[ns]
#  3   region            9643 non-null   object
#  4   state             9643 non-null   object
#  5   city              9643 non-null   object
#  6   product           9643 non-null   object
#  7   price_per_unit    9643 non-null   int64
#  8   units_sold        9643 non-null   int64
#  9   total_sales       9643 non-null   int64
#  10  operating_profit  9643 non-null   float64
#  11  sales_method      9643 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(6)
# memory usage: 904.2+ KB

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".

# Combine the DataFrames by rows using an inner join, group by region, state, and city, sum the units_sold, rename the sum column
products_sold = pd.concat([sales_2020, sales_2021]) \
    .groupby(['region', 'state', 'city'])['units_sold'].sum() \
    .reset_index() \
    .rename(columns={'units_sold': 'Total_Products_Sold'})

# Sort the DataFrame by "Total_Products_Sold" in descending order and show the top 5 results
top_5_results = products_sold.sort_values(by='Total_Products_Sold', ascending=False).head(5)

(top_5_results)
# Out:
#        region       state           city  Total_Products_Sold
# 21  Northeast    New York       New York               111954
# 33      South       Texas        Houston                90322
# 44       West  California  San Francisco                85478
# 43       West  California    Los Angeles                76384
# 34  Southeast     Florida          Miami                73135

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
# Rename the "units_sold" column to "Total_Products_Sold"
# Show the top 5 results

# Read the dataset into a DataFrame
data = {
    'region': ['Northeast', 'South', 'West', 'West', 'Southeast'],
    'state': ['New_York', 'Texas', 'California', 'California', 'Florida'],
    'city': ['New_York', 'Houston', 'San_Francisco', 'Los_Angeles', 'Miami'],
    'products_sold': [111954, 90322, 85478, 76384, 73135]
}

df = pd.DataFrame(data)

# Use pivot_table to pivot the data and aggregate the products sold
pivot_df = pd.pivot_table(df, index=['region', 'state', 'city'], values='products_sold', aggfunc='sum')

# Rename the aggregated column
pivot_df.rename(columns={'products_sold': 'Total_Products_Sold'}, inplace=True)

# Sort the results in descending order and display the top 5 results
top_5_results = pivot_df.sort_values(by='Total_Products_Sold', ascending=False).head(5)

(top_5_results)
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New_York   New_York                    111954
# South     Texas      Houston                      90322
# West      California San_Francisco                85478
#                      Los_Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"

# Combine the DataFrames by rows using an inner join, group by region, state, and city, sum the total_sales, rename the sum column, and show the top 5 results
top_5_sales = pd.concat([sales_2020, sales_2021]) \
    .groupby(['region', 'state', 'city'])['total_sales'].sum() \
    .reset_index() \
    .rename(columns={'total_sales': 'Total Sales'}) \
    .sort_values(by='Total Sales', ascending=False) \
    .head(5)

(top_5_sales)
# Out:
#        region           state           city  Total Sales
# 21  Northeast        New York       New York     39801235
# 44       West      California  San Francisco     33973228
# 34  Southeast         Florida          Miami     31600863
# 39  Southeast  South Carolina     Charleston     29285637
# 35  Southeast         Florida        Orlando     27682851

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.

# Combine the DataFrames by rows using an inner join
combined_sales = pd.concat([sales_2020, sales_2021])

# Group by region, state, and city, sum the total_sales, and show the top 5 results
top_5_sales = combined_sales.groupby(['region', 'state', 'city'])['total_sales'].sum().reset_index()

# Optional: Rename the "total_sales" column to "Total Sales"
top_5_sales.rename(columns={'total_sales': 'Total Sales'}, inplace=True)

# Show the top 5 results.
top_5_results = top_5_sales.nlargest(5, 'Total Sales')

(top_5_results)
# Out:
#        region           state           city  Total Sales
# 21  Northeast        New York       New York     39801235
# 44       West      California  San Francisco     33973228
# 34  Southeast         Florida          Miami     31600863
# 39  Southeast  South Carolina     Charleston     29285637
# 35  Southeast         Florida        Orlando     27682851

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"

# Combine the DataFrames by rows using an inner join
combined_sales = pd.concat([sales_2020, sales_2021])

# Group by retailer, region, state, and city, sum the total_sales, and show the top 5 results
top_sales = combined_sales.groupby(['retailer', 'region', 'state', 'city'])['total_sales'].sum().reset_index()
top_sales.rename(columns={'total_sales': 'Total Sales'}, inplace=True)


# Show the top 5 results.
top_5_results = top_sales.sort_values(by='Total Sales', ascending=False).head(5)

(top_5_results)
# Out:
#         retailer     region           state           city  Total Sales
# 103    West Gear       West      California  San Francisco     32794405
# 50        Kohl's       West      California    Los Angeles     25127160
# 22   Foot Locker  Northeast        New York       New York     25008568
# 109    West Gear       West      Washington        Seattle     24862675
# 33   Foot Locker  Southeast  South Carolina     Charleston     24822280

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.

# Optional: Rename the "total_sales" column to "Total Sales"
# Combine the DataFrames by rows using an inner join
combined_sales = pd.concat([df_2020, df_2021])

# Group by retailer, region, state, and city, sum the total_sales, and rename the column
sales_summary = combined_sales.groupby(['retailer', 'region', 'state', 'city'])['total_sales'].sum().reset_index()
sales_summary.rename(columns={'total_sales': 'Total Sales'}, inplace=True)

# Show the top 5 results.
top_5_results = sales_summary.nlargest(5, 'Total Sales')

(top_5_results)
# Out:
#         retailer     region           state           city  Total Sales
# 103    West Gear       West      California  San Francisco     32794405
# 50        Kohl's       West      California    Los Angeles     25127160
# 22   Foot Locker  Northeast        New York       New York     25008568
# 109    West Gear       West      Washington        Seattle     24862675
# 33   Foot Locker  Southeast  South Carolina     Charleston     24822280

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.

# Combine the DataFrames by rows using an inner join
combined_sales = pd.concat([df_2020, df_2021])

# Filter the sales data to get women's athletic footwear sales data
womens_footwear_sales = combined_sales[combined_sales['product'].str.contains("Women's Athletic Footwear")]

(womens_footwear_sales)
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 21    Foot Locker      1185732       1/4/20  Northeast      New York
# 22    Foot Locker      1185732       1/4/20  Northeast      New York
# 23    Foot Locker      1185732       1/4/20  Northeast      New York
# 26      West Gear      1128299       1/5/20  Northeast  Pennsylvania
# 27      West Gear      1128299       1/5/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 8336  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 8337  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 8338       Amazon      1185732     12/30/21  Northeast         Maine
# 8339       Amazon      1185732     12/30/21  Northeast         Maine
# 8340  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
#
#               city                    product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

# Combine the DataFrames by rows using an inner join
combined_sales = pd.concat([df_2020, df_2021])

# Filter the sales data to get women's athletic footwear sales data
womens_footwear_sales = combined_sales[combined_sales['product'].str.contains("Women's Athletic Footwear")]

# Group by retailer, region, state, and city, sum the units_sold, and rename the column
womens_footwear_summary = womens_footwear_sales.groupby(['retailer', 'region', 'state', 'city'])['units_sold'].sum().reset_index()
womens_footwear_summary.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'}, inplace=True)

# Show the top 5 results.
top_5_results = womens_footwear_summary.nlargest(5, 'Womens_Footwear_Units_Sold')

(top_5_results)
# Out:
#           retailer     region           state           city  \
# 101      West Gear       West      California  San Francisco
# 22     Foot Locker  Northeast        New York       New York
# 49          Kohl's       West      California    Los Angeles
# 33     Foot Locker  Southeast  South Carolina     Charleston
# 68   Sports Direct      South           Texas         Dallas
#
#      Womens_Footwear_Units_Sold
# 101                       12107
# 22                        10996
# 49                        10826
# 33                         8814
# 68                         8790

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.

# Combine the DataFrames by rows using an inner join
combined_sales = pd.concat([df_2020, df_2021])

# Filter the sales data to get women's athletic footwear sales data
womens_footwear_sales = combined_sales[combined_sales['product'].str.contains("Women's Athletic Footwear")]

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
# Group by retailer, region, state, and city, sum the units_sold, and rename the column
womens_footwear_summary = womens_footwear_sales.groupby(['retailer', 'region', 'state', 'city'])['units_sold'].sum().reset_index()
womens_footwear_summary.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'}, inplace=True)

# Show the top 5 results.
top_5_results = womens_footwear_summary.nlargest(5, 'Womens_Footwear_Units_Sold')

(top_5_results)
# Out:
#           retailer     region           state           city  \
# 101      West Gear       West      California  San Francisco
# 22     Foot Locker  Northeast        New York       New York
# 49          Kohl's       West      California    Los Angeles
# 33     Foot Locker  Southeast  South Carolina     Charleston
# 68   Sports Direct      South           Texas         Dallas
#
#      Womens_Footwear_Units_Sold
# 101                       12107
# 22                        10996
# 49                        10826
# 33                         8814
# 68                         8790

# %%
womens_footwear_sales
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 21    Foot Locker      1185732       1/4/20  Northeast      New York
# 22    Foot Locker      1185732       1/4/20  Northeast      New York
# 23    Foot Locker      1185732       1/4/20  Northeast      New York
# 26      West Gear      1128299       1/5/20  Northeast  Pennsylvania
# 27      West Gear      1128299       1/5/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 8336  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 8337  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 8338       Amazon      1185732     12/30/21  Northeast         Maine
# 8339       Amazon      1185732     12/30/21  Northeast         Maine
# 8340  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
#
#               city                    product  price_per_unit  units_sold  \
# ...

# %%
womens_footwear_sales.pivot_table?
# Out:
# Signature:
# womens_footwear_sales.pivot_table(
#     values=None,
#     index=None,
#     columns=None,
#     aggfunc: 'AggFuncType' = 'mean',
#     fill_value=None,
#     margins: 'bool' = False,
#     dropna: 'bool' = True,
#     margins_name: 'Level' = 'All',
#     observed: 'bool' = False,
#     sort: 'bool' = True,
# ) -> 'DataFrame'
# Docstring:
# Create a spreadsheet-style pivot table as a DataFrame.
#
# The levels in the pivot table will be stored in MultiIndex objects
# (hierarchical indexes) on the index and columns of the result DataFrame.
#
# Parameters
# ----------
# values : list-like or scalar, optional
#     Column or columns to aggregate.
# index : column, Grouper, array, or list of the previous
#     Keys to group by on the pivot table index. If a list is passed,
#     it can contain any of the other types (except list). If an array is
#     passed, it must be the same length as the data and will be used in
#     the same manner as column values.
# ...

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
pd.pivot_table(womens_footwear_sales, values='total_sales', index=['invoice_date'],
                                  aggfunc="sum")

# Optional: Rename the "total_sales" column to "Total Sales"



# Show the table.
(pivot_table)
# Out:
#               Total Sales
# invoice_date
# 2020-01-01         845141
# 2020-01-02         689410
# 2020-01-03         632573
# 2020-01-04         615080
# 2020-01-05         707829
# ...                   ...
# 2021-12-27         602353
# 2021-12-28         301010
# 2021-12-29         211109
# 2021-12-30         167903
# 2021-12-31         198659
#
# [723 rows x 1 columns]

# %% [markdown]
# ### 6. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
womens_footwear_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1604 entries, 21 to 8340
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          1604 non-null   object
#  1   retailer_id       1604 non-null   int64
#  2   invoice_date      1604 non-null   object
#  3   region            1604 non-null   object
#  4   state             1604 non-null   object
#  5   city              1604 non-null   object
#  6   product           1604 non-null   object
#  7   price_per_unit    1604 non-null   int64
#  8   units_sold        1604 non-null   int64
#  9   total_sales       1604 non-null   int64
#  10  operating_profit  1604 non-null   float64
#  11  sales_method      1604 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 162.9+ KB

# %%
womens_footwear_sales['invoice_date'] = pd.to_datetime(womens_footwear_sales['invoice_date'], errors = 'coerce')
womens_footwear_sales
# Out:
# C:\Users\KTray\AppData\Local\Temp\ipykernel_35184\3322648492.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   womens_footwear_sales['invoice_date'] = pd.to_datetime(womens_footwear_sales['invoice_date'], errors = 'coerce')
# C:\Users\KTray\AppData\Local\Temp\ipykernel_35184\3322648492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   womens_footwear_sales['invoice_date'] = pd.to_datetime(womens_footwear_sales['invoice_date'], errors = 'coerce')
#          retailer  retailer_id invoice_date     region         state  \
# 21    Foot Locker      1185732   2020-01-04  Northeast      New York
# ...

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
womens_athletic = pd.pivot_table(womens_footwear_sales, values='total_sales', index=['invoice_date'],
                                  aggfunc="sum")

# Optional: Rename the "total_sales" column to "Total Sales"



# Show the table.
womens_athletic
# Out:
#               total_sales
# invoice_date
# 2020-01-04         402743
# 2020-01-05         141801
# 2020-01-11         129556
# 2020-01-17         173013
# 2020-01-22         388250
# ...                   ...
# 2021-12-22         200406
# 2021-12-23         808022
# 2021-12-24         190885
# 2021-12-25         315175
# 2021-12-30         167903
#
# [355 rows x 1 columns]

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.

total_sales = womens_athletic.resample('D').sum()

# Sort the resampled pivot table in descending order on "Total Sales"
daily_sales_sorted = total_sales.sort_values(by='total_sales', ascending=False)

daily_sales_sorted.head()
# Out:
#               total_sales
# invoice_date
# 2021-07-16        1521825
# 2021-12-16        1473497
# 2021-06-17        1376988
# 2021-08-17        1086294
# 2021-07-23        1021806

# %% [markdown]
# ### 7.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.

weekly_sales = womens_footwear_pivot.resample('W').sum()

# Sort the resampled pivot table in descending order on "Total Sales"
weekly_sales_sorted = weekly_sales.sort_values(by='total_sales', ascending=False)

weekly_sales_sorted
# Out:
#               total_sales
# invoice_date
# 2021-12-19        3098970
# 2021-12-12        2922161
# 2021-07-11        2835078
# 2021-07-18        2801449
# 2021-11-14        2531721
# ...                   ...
# 2020-12-06          62801
# 2020-12-20          61710
# 2020-12-13          58916
# 2020-11-22          53940
# 2020-10-18              0
#
# [105 rows x 1 columns]
